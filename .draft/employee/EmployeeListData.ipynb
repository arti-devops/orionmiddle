# %%
import json
import types
import requests

# %%
class Namespace:
    def __init__(self, adict):
        self.__dict__.update(adict)

# %%
#base_link = "http://localhost:8080/api/v1/"
base_link = "http://192.168.0.218:8080/api/v1/"

# %%
links = {
    "position":Namespace({
        "all":"position/all",
        "all_active":"position/all/active",
        "single":"position/"
    }),
    "employee":Namespace({
        "all":"employee/all",
        "single":"employee/"
    }),
    "task":Namespace({
        "all":"task/all",
        "single":"task/"
    }),
    "taskrole":Namespace({
        "all":"taskrole/all",
        "single":"taskrole/",
        "position":"taskrole/position/"
    }),
    "logbook":Namespace({
        "all":"logbook/all",
        "range":"logbook/range/", #{s}/{e}
        "prange":"logbook/range/",#{p}/{s}/{e}
        "single":"logbook/"
    }),
    "absence":Namespace({
        "all":"absence/all",
        "range":"absence/range/", #{s}/{e}
        "prange":"absence/range/",#{p}/{s}/{e}
        "single":"absence/"
    })
};links_ns = Namespace(links)

# %%
def get_direction_name(p):
    p = Namespace(p)
    if p.service is not None:
        subdiv = p.service["subdivision"]
        subdiv = Namespace(subdiv)
        if subdiv.direction is not None:
            return subdiv.direction["shortName"]
        else: return subdiv.shortName
    else:
        div = p.subdivision["direction"]
        if div is not None:
            return div["shortName"]
        else: return p.subdivision["shortName"]
        
def get_service_name(p):
    p = Namespace(p)
    if p.service is not None:
        return p.service["name"]
    else:
        return "AUCUN"

# %%
def get_employee_list_bio_data():
    emp_data_list = list()
    positions = requests.get(base_link+links_ns.position.all_active).json()
    for p in positions:
        emp_data = dict()
        emp_data["position_id"] = p["positionId"]
        emp_data["employee_id"] = p["employee"]["employeeId"]
        emp_data["fullname"] = p["employee"]["lastName"] +" "+ p["employee"]["firstName"].strip() 
        emp_data["matricula"] = p["employee"]["matricule"]
        emp_data["rolename"] = p["role"]["name"]
        emp_data["service"] = get_service_name(p)
        emp_data["direction"] = get_direction_name(p)
        emp_data["email"] = p["employee"]["email"]
        emp_data["contact"] = p["employee"]["contact"]
        emp_data["location"] = p["location"]
        emp_data_list.append(emp_data)
    return emp_data_list

# %%
#get_employee_list_bio_data()
emp_list = get_employee_list_bio_data()

# %%
import pandas as pd
import datetime as dt
from datetime import datetime, timedelta

#date_string = "2023-03-01" "%Y-%m-%d"

def extract_year_from_date(date_string:str):
    date_obj = datetime.strptime(date_string, "%Y-%m-%d")
    return date_obj.year

def extract_month_from_date(date_string:str):
    date_obj = datetime.strptime(date_string, "%Y-%m-%d")
    return date_obj.month

def extract_workdays_in_month(year, month):
    start_date = dt.date(year, month, 1)
    end_date = dt.date(year, month+1, 1) - dt.timedelta(days=1)
    return pd.bdate_range(start_date, end_date, freq='C').size

# %%
def compute_time_diff_in_minutes(checkin:str):
    time1 = '08:10:00'
    time2 = checkin
    dt1 = datetime.strptime(time1, '%H:%M:%S')
    dt2 = datetime.strptime(time2, '%H:%M:%S')
    time_diff = dt1 - dt2
    minutes_diff = time_diff.total_seconds() / 60.0
    return minutes_diff

def count_late_occurence(minuteDiffs:list):
    occurences = [1 for t in minuteDiffs if t<0]
    return len(occurences)

def count_no_log_occurence(nb_log:int, date_string:str):
    n_work_days = compute_word_days_in_month(date_string)
    return n_work_days - nb_log

def compute_word_days_in_month(date_string:str):
    year = extract_year_from_date(date_string)
    month = extract_month_from_date(date_string)
    return extract_workdays_in_month(year, month)

def generate_daterange_link(link:links_ns, p, s, e):
    """Link namespace"""
    return base_link+link.prange+ str(p) +"/"+ s +"/"+ e

def generate_position_req_link(link:links_ns, p):
    """Link namespace"""
    return base_link + link.position + str(p)

# %%
def get_employee_list_checkin_data(emp_list, start_date:str, end_date:str):
    log_data_list = []
    for emp in emp_list:

        logd = dict()

        e = Namespace(emp)
        pid = e.position_id

        lc = generate_daterange_link(links_ns.logbook, pid, start_date, end_date)
        la = generate_daterange_link(links_ns.absence, pid, start_date, end_date)

        reqa = requests.get(la)
        reqc = requests.get(lc)

        loga = reqa.json()
        logc = reqc.json()

        #logd["position_id"] = pid
        logd["checkins"] = len(logc)
        logd["no_checkins"] = count_no_log_occurence(len(logc), start_date)
        logd["late_arrivals"] = count_late_occurence([compute_time_diff_in_minutes(c["checkinTime"]) for c in logc])
        logd["absences"] = len(loga)
        logd["abs_justified"] = len([1 for a in loga if a["justified"]=="yes"])

        log_data_list.append(logd)
        emp["logs"] = logd
    return emp_list, log_data_list

# %%
emp_list_1 = get_employee_list_checkin_data(emp_list,"2023-04-01","2023-04-30")[0]

# %%
def compute_nb_finished_tasks(taskrole):
    finished = [x["task"]["status"] for x in taskrole if x["task"]["status"]=="FINISHED"]
    return len(finished)

def compute_progress(finished:int, nb:int):
    return finished/nb*100

# %%
def get_employee_list_task_data(emp_list):
    task_data_list = []
    for emp in emp_list:

        taskd = dict()

        e = Namespace(emp)
        pid = e.position_id

        l = generate_position_req_link(links_ns.taskrole, pid)

        d = requests.get(l).json()

        if len(d) == 0:
            task_data = {"nb_task":0,"nb_finished":0,"progress":0}
        else:
            nb = len(d)
            finished = compute_nb_finished_tasks(d)
            progress = compute_progress(finished, nb)

            task_data = {"nb_task":nb, "nb_finished": finished, "progress":progress}

        task_data_list.append(task_data)
        emp["tasks"] = task_data
    return emp_list, task_data_list

# %%
get_employee_list_task_data(emp_list_1)[0]
# Out:
# [{'position_id': 1,
#   'employee_id': 1,
#   'fullname': 'ANGOUA YOBOUATH GUY CHARLES',
#   'matricula': '1080720A',
#   'rolename': 'SOUS-DIRECTEUR',
#   'service': 'AUCUN',
#   'direction': 'DSI',
#   'email': 'guy-charles.angoua@arti.ci',
#   'contact': '',
#   'location': 'ABIDJAN',
#   'logs': {'checkins': 1,
#    'no_checkins': 19,
#    'late_arrivals': 0,
#    'absences': 3,
#    'abs_justified': 3},
#   'tasks': {'nb_task': 0, 'nb_finished': 0, 'progress': 0}},
#  {'position_id': 2,
#   'employee_id': 2,
#   'fullname': 'ANOH AMA LISETTE DESIREE Epse AFFANOU',
#   'matricula': '2270921A',
#   'rolename': 'AGENT',
#   'service': 'SERVICE DE LA COMMUNICATION',
#   'direction': 'DCP',
#   'email': 'lisette.affanou@arti.ci',
#   'contact': '0799852917',
#   'location': 'ABIDJAN',
#   'logs': {'checkins': 4,
#    'no_checkins': 16,
#    'late_arrivals': 2,
#    'absences': 1,
#    'abs_justified': 1},
#   'tasks': {'nb_task': 0, 'nb_finished': 0, 'progress': 0}},
#  {'position_id': 3,
#   'employee_id': 3,
#   'fullname': 'BAILLY ERIC THEODORE',
#   'matricula': '1390722B',
#   'rolename': 'AGENT',
#   'service': 'AUCUN',
#   'direction': 'DAAF',
#   'email': 'eric.bailly@arti.ci',
#   'contact': '',
#   'location': 'ABIDJAN',
#   'logs': {'checkins': 3,
#    'no_checkins': 17,
#    'late_arrivals': 1,
#    'absences': 3,
#    'abs_justified': 1},
#   'tasks': {'nb_task': 0, 'nb_finished': 0, 'progress': 0}},
#  {'position_id': 4,
#   'employee_id': 4,
#   'fullname': 'BEN MOURAD MOHAMED ALY',
#   'matricula': '1230521B',
#   'rolename': 'CHEF DE SERVICE',
#   'service': 'SERVICE DU CONTROLE',
#   'direction': 'DCSTI',
#   'email': 'ben.mourad@arti.ci',
#   'contact': '',
#   'location': 'ABIDJAN',
#   'logs': {'checkins': 4,
#    'no_checkins': 16,
#    'late_arrivals': 2,
#    'absences': 5,
#    'abs_justified': 1},
#   'tasks': {'nb_task': 0, 'nb_finished': 0, 'progress': 0}},
#  {'position_id': 5,
#   'employee_id': 5,
#   'fullname': 'BOKOUA ZIOGBA SEBASTIEN',
#   'matricula': '1281021B',
#   'rolename': 'SOUS-DIRECTEUR',
#   'service': 'AUCUN',
#   'direction': 'DSESP',
#   'email': 'sebastien.bokoua@arti.ci',
#   'contact': '',
#   'location': 'ABIDJAN',
#   'logs': {'checkins': 3,
#    'no_checkins': 17,
#    'late_arrivals': 2,
#    'absences': 7,
#    'abs_justified': 3},
#   'tasks': {'nb_task': 1, 'nb_finished': 0, 'progress': 0.0}},
#  {'position_id': 6,
#   'employee_id': 6,
#   'fullname': 'CISSE ALASSANE AL MOUSTAPHA',
#   'matricula': '1260921C',
#   'rolename': 'CHEF DE SERVICE',
#   'service': 'SERVICE RECHERCHE ET DEVELOPPEMENT',
#   'direction': 'DSESP',
#   'email': 'al-moustapha.cisse@arti.ci',
#   'contact': '0799852919',
#   'location': 'ABIDJAN',
#   'logs': {'checkins': 1,
#    'no_checkins': 19,
#    'late_arrivals': 0,
#    'absences': 3,
#    'abs_justified': 1},
#   'tasks': {'nb_task': 4, 'nb_finished': 1, 'progress': 25.0}},
#  {'position_id': 7,
#   'employee_id': 7,
#   'fullname': 'COULIBALY MOUSSA',
#   'matricula': '1150820C',
#   'rolename': 'AGENT',
#   'service': 'GESTION DU PATRIMOINE ET DES MOYENS GENERAUX ',
#   'direction': 'DMGP',
#   'email': 'moussa.coulibaly@arti.ci',
#   'contact': '',
#   'location': 'ABIDJAN',
#   'logs': {'checkins': 2,
#    'no_checkins': 18,
#    'late_arrivals': 1,
#    'absences': 2,
#    'abs_justified': 2},
#   'tasks': {'nb_task': 0, 'nb_finished': 0, 'progress': 0}},
#  {'position_id': 8,
#   'employee_id': 8,
#   'fullname': 'DEBEY ALLEGUY LINDA CAROLE',
#   'matricula': '2090720D',
#   'rolename': 'CHEF DE SERVICE',
#   'service': 'GESTION DU PATRIMOINE ET DES MOYENS GENERAUX ',
#   'direction': 'DMGP',
#   'email': 'lynda.debey@arti.ci',
#   'contact': '',
#   'location': 'ABIDJAN',
#   'logs': {'checkins': 1,
#    'no_checkins': 19,
#    'late_arrivals': 0,
#    'absences': 3,
#    'abs_justified': 2},
#   'tasks': {'nb_task': 0, 'nb_finished': 0, 'progress': 0}},
#  {'position_id': 9,
#   'employee_id': 9,
#   'fullname': 'DIABAGATE MOHAMMED',
#   'matricula': '1230521D',
#   'rolename': 'CHEF DE SERVICE',
#   'service': 'SERVICE DE LA SURVEILLANCE',
#   'direction': 'DCSTI',
#   'email': 'mohammed.diabagate@arti.ci',
#   'contact': '',
#   'location': 'BOUAKE',
#   'logs': {'checkins': 0,
#    'no_checkins': 20,
#    'late_arrivals': 0,
#    'absences': 1,
#    'abs_justified': 0},
#   'tasks': {'nb_task': 0, 'nb_finished': 0, 'progress': 0}},
#  {'position_id': 10,
#   'employee_id': 10,
#   'fullname': 'DJIRE KELETIGUI LAMINE',
#   'matricula': '1400822D',
#   'rolename': 'SOUS-DIRECTEUR',
#   'service': 'AUCUN',
#   'direction': 'DSESP',
#   'email': 'lamine.djire@arti.ci',
#   'contact': '',
#   'location': 'ABIDJAN',
#   'logs': {'checkins': 1,
#    'no_checkins': 19,
#    'late_arrivals': 0,
#    'absences': 4,
#    'abs_justified': 3},
#   'tasks': {'nb_task': 2, 'nb_finished': 0, 'progress': 0.0}},
#  {'position_id': 11,
#   'employee_id': 11,
#   'fullname': 'ENAN EBLOTCHE JEAN-JACQUES',
#   'matricula': '1340222E',
#   'rolename': 'CHEF DE SERVICE',
#   'service': 'PASSATION DES MARCHES',
#   'direction': 'DMGP',
#   'email': 'jj.enan@arti.ci',
#   'contact': '',
#   'location': 'ABIDJAN',
#   'logs': {'checkins': 1,
#    'no_checkins': 19,
#    'late_arrivals': 0,
#    'absences': 6,
#    'abs_justified': 3},
#   'tasks': {'nb_task': 0, 'nb_finished': 0, 'progress': 0}},
#  {'position_id': 12,
#   'employee_id': 12,
#   'fullname': 'FOFANA SIMON',
#   'matricula': '1410922F',
#   'rolename': 'CHEF DE SERVICE',
#   'service': 'SERVICE D’ADMINISTRATION DES RESSOURCES HUMAINES ',
#   'direction': 'DGPECRP',
#   'email': 'simon.fofana@arti.ci',
#   'contact': '',
#   'location': 'ABIDJAN',
#   'logs': {'checkins': 1,
#    'no_checkins': 19,
#    'late_arrivals': 1,
#    'absences': 2,
#    'abs_justified': 2},
#   'tasks': {'nb_task': 0, 'nb_finished': 0, 'progress': 0}},
#  {'position_id': 13,
#   'employee_id': 13,
#   'fullname': 'GBAMELE KOUASSI SIMEON',
#   'matricula': '1291021G',
#   'rolename': 'AGENT',
#   'service': 'GESTION DU PATRIMOINE ET DES MOYENS GENERAUX ',
#   'direction': 'DMGP',
#   'email': None,
#   'contact': '',
#   'location': 'ABIDJAN',
#   'logs': {'checkins': 1,
#    'no_checkins': 19,
#    'late_arrivals': 0,
#    'absences': 2,
#    'abs_justified': 1},
#   'tasks': {'nb_task': 0, 'nb_finished': 0, 'progress': 0}},
#  {'position_id': 14,
#   'employee_id': 14,
#   'fullname': 'GNAGNE MEL PATRICK SERGES',
#   'matricula': '1360322G',
#   'rolename': 'AGENT',
#   'service': 'AUCUN',
#   'direction': 'DRRN',
#   'email': 'serge.gnagne@arti.ci',
#   'contact': '',
#   'location': 'ABIDJAN',
#   'logs': {'checkins': 2,
#    'no_checkins': 18,
#    'late_arrivals': 2,
#    'absences': 1,
#    'abs_justified': 1},
#   'tasks': {'nb_task': 0, 'nb_finished': 0, 'progress': 0}},
#  {'position_id': 15,
#   'employee_id': 15,
#   'fullname': 'GRAH FRANCK',
#   'matricula': '1380722G ',
#   'rolename': 'AGENT',
#   'service': 'GESTION DU PATRIMOINE ET DES MOYENS GENERAUX ',
#   'direction': 'DMGP',
#   'email': None,
#   'contact': '',
#   'location': 'ABIDJAN',
#   'logs': {'checkins': 3,
#    'no_checkins': 17,
#    'late_arrivals': 1,
#    'absences': 2,
#    'abs_justified': 2},
#   'tasks': {'nb_task': 0, 'nb_finished': 0, 'progress': 0}},
#  {'position_id': 16,
#   'employee_id': 16,
#   'fullname': 'KABLAN JEAN CLAUDE',
#   'matricula': '1180820K',
#   'rolename': 'AGENT',
#   'service': 'GESTION DU PATRIMOINE ET DES MOYENS GENERAUX ',
#   'direction': 'DMGP',
#   'email': None,
#   'contact': '',
#   'location': 'ABIDJAN',
#   'logs': {'checkins': 2,
#    'no_checkins': 18,
#    'late_arrivals': 1,
#    'absences': 1,
#    'abs_justified': 0},
#   'tasks': {'nb_task': 0, 'nb_finished': 0, 'progress': 0}},
#  {'position_id': 17,
#   'employee_id': 17,
#   'fullname': 'KOSSIKE KANGO SERAPHIN',
#   'matricula': '1110720K',
#   'rolename': 'AGENT',
#   'service': 'GESTION DU PATRIMOINE ET DES MOYENS GENERAUX ',
#   'direction': 'DMGP',
#   'email': None,
#   'contact': '',
#   'location': 'ABIDJAN',
#   'logs': {'checkins': 1,
#    'no_checkins': 19,
#    'late_arrivals': 0,
#    'absences': 7,
#    'abs_justified': 5},
#   'tasks': {'nb_task': 0, 'nb_finished': 0, 'progress': 0}},
#  {'position_id': 18,
#   'employee_id': 18,
#   'fullname': 'KOUADIO KONAN EDMOND',
#   'matricula': '1350322K',
#   'rolename': 'AGENT',
#   'service': 'AUCUN',
#   'direction': 'DRRN',
#   'email': 'edmond.kouadio@arti.ci',
#   'contact': '',
#   'location': 'ABIDJAN',
#   'logs': {'checkins': 0,
#    'no_checkins': 20,
#    'late_arrivals': 0,
#    'absences': 1,
#    'abs_justified': 1},
#   'tasks': {'nb_task': 0, 'nb_finished': 0, 'progress': 0}},
#  {'position_id': 19,
#   'employee_id': 19,
#   'fullname': 'KOUASSI KOUAME ADRIEN',
#   'matricula': '1210221K',
#   'rolename': 'AGENT',
#   'service': 'AUCUN',
#   'direction': 'DAAF',
#   'email': 'adrien.kouassi@arti.ci',
#   'contact': '',
#   'location': 'ABIDJAN',
#   'logs': {'checkins': 2,
#    'no_checkins': 18,
#    'late_arrivals': 2,
#    'absences': 5,
#    'abs_justified': 2},
#   'tasks': {'nb_task': 0, 'nb_finished': 0, 'progress': 0}},
#  {'position_id': 20,
#   'employee_id': 20,
#   'fullname': 'KUE KAMONIAN VALENTIN',
#   'matricula': '1120720K',
#   'rolename': 'AGENT',
#   'service': 'GESTION DU PATRIMOINE ET DES MOYENS GENERAUX ',
#   'direction': 'DMGP',
#   'email': None,
#   'contact': '',
#   'location': 'ABIDJAN',
#   'logs': {'checkins': 3,
#    'no_checkins': 17,
#    'late_arrivals': 1,
#    'absences': 3,
#    'abs_justified': 1},
#   'tasks': {'nb_task': 0, 'nb_finished': 0, 'progress': 0}},
#  {'position_id': 21,
#   'employee_id': 21,
#   'fullname': 'MANOUAN THECLE NINA Epse KONE',
#   'matricula': '2140820M',
#   'rolename': 'AGENT',
#   'service': 'AUCUN',
#   'direction': 'CR',
#   'email': 'nina.kone@arti.ci',
#   'contact': '',
#   'location': 'ABIDJAN',
#   'logs': {'checkins': 1,
#    'no_checkins': 19,
#    'late_arrivals': 0,
#    'absences': 1,
#    'abs_justified': 1},
#   'tasks': {'nb_task': 0, 'nb_finished': 0, 'progress': 0}},
#  {'position_id': 22,
#   'employee_id': 22,
#   'fullname': "N'DA NIAMKEY ELYSEE Epse SEMI",
#   'matricula': '2160820N',
#   'rolename': 'AGENT',
#   'service': 'GESTION DU PATRIMOINE ET DES MOYENS GENERAUX ',
#   'direction': 'DMGP',
#   'email': 'elysee.semi@arti.ci',
#   'contact': '',
#   'location': 'ABIDJAN',
#   'logs': {'checkins': 2,
#    'no_checkins': 18,
#    'late_arrivals': 0,
#    'absences': 1,
#    'abs_justified': 1},
#   'tasks': {'nb_task': 0, 'nb_finished': 0, 'progress': 0}},
#  {'position_id': 23,
#   'employee_id': 23,
#   'fullname': 'NOGBOU ABODJOH PAULE',
#   'matricula': '2060620N',
#   'rolename': 'AGENT',
#   'service': 'AUCUN',
#   'direction': 'DG',
#   'email': 'paule.nogbou@arti.ci',
#   'contact': '',
#   'location': 'ABIDJAN',
#   'logs': {'checkins': 1,
#    'no_checkins': 19,
#    'late_arrivals': 0,
#    'absences': 3,
#    'abs_justified': 2},
#   'tasks': {'nb_task': 0, 'nb_finished': 0, 'progress': 0}},
#  {'position_id': 24,
#   'employee_id': 24,
#   'fullname': 'OLOUI AGANY IBIDON YVES',
#   'matricula': '1250921O',
#   'rolename': 'CHEF DE SERVICE',
#   'service': "SERVICE DE L'AUDIT",
#   'direction': 'DSESP',
#   'email': 'yves.oloui@arti.ci',
#   'contact': '0799852918',
#   'location': 'ABIDJAN',
#   'logs': {'checkins': 2,
#    'no_checkins': 18,
#    'late_arrivals': 0,
#    'absences': 1,
#    'abs_justified': 0},
#   'tasks': {'nb_task': 0, 'nb_finished': 0, 'progress': 0}},
#  {'position_id': 25,
#   'employee_id': 25,
#   'fullname': 'SAMBARE ZAKARIA',
#   'matricula': '1100720S',
#   'rolename': 'AGENT',
#   'service': 'GESTION DU PATRIMOINE ET DES MOYENS GENERAUX ',
#   'direction': 'DMGP',
#   'email': None,
#   'contact': '',
#   'location': 'ABIDJAN',
#   'logs': {'checkins': 0,
#    'no_checkins': 20,
#    'late_arrivals': 0,
#    'absences': 2,
#    'abs_justified': 2},
#   'tasks': {'nb_task': 0, 'nb_finished': 0, 'progress': 0}},
#  {'position_id': 26,
#   'employee_id': 26,
#   'fullname': 'SEYNOU AICHA',
#   'matricula': '2301021S',
#   'rolename': 'AGENT',
#   'service': 'AUCUN',
#   'direction': 'DCP',
#   'email': 'aicha.seynou@arti.ci',
#   'contact': '',
#   'location': 'ABIDJAN',
#   'logs': {'checkins': 1,
#    'no_checkins': 19,
#    'late_arrivals': 0,
#    'absences': 3,
#    'abs_justified': 1},
#   'tasks': {'nb_task': 0, 'nb_finished': 0, 'progress': 0}},
#  {'position_id': 27,
#   'employee_id': 27,
#   'fullname': 'WILSON GEORGES HONORE MENSAH',
#   'matricula': '1240821W',
#   'rolename': 'AGENT',
#   'service': 'GESTION DU PATRIMOINE ET DES MOYENS GENERAUX ',
#   'direction': 'DMGP',
#   'email': None,
#   'contact': '',
#   'location': 'ABIDJAN',
#   'logs': {'checkins': 1,
#    'no_checkins': 19,
#    'late_arrivals': 0,
#    'absences': 1,
#    'abs_justified': 1},
#   'tasks': {'nb_task': 0, 'nb_finished': 0, 'progress': 0}},
#  {'position_id': 28,
#   'employee_id': 28,
#   'fullname': 'YAO ANYELA MARIE COLOMBE Epse ADOU',
#   'matricula': '2170820Y',
#   'rolename': 'AGENT',
#   'service': 'AUCUN',
#   'direction': 'DGPECRP',
#   'email': 'anyela.yao@arti.ci',
#   'contact': '',
#   'location': 'ABIDJAN',
#   'logs': {'checkins': 2,
#    'no_checkins': 18,
#    'late_arrivals': 0,
#    'absences': 2,
#    'abs_justified': 2},
#   'tasks': {'nb_task': 0, 'nb_finished': 0, 'progress': 0}}]
