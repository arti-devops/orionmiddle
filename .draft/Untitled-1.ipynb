# %%
import pandas as pd
import requests

# %% [markdown]
# #The code goes here

# %%
r = requests.get("https://google.com")

# %%
r.content
# Out:
# b'<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="fr-CI"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="JrAw9EdmKsY0Ntvidy_KnA">(function(){window.google={kEI:\'jGo9ZPfxAvaqkdUP2KGisAk\',kEXPI:\'0,1359409,6058,207,4804,2316,383,246,5,1129120,1197745,656,380090,16114,19398,9286,22431,1361,12311,17588,4998,13228,3847,38444,2872,2891,4139,4209,3406,606,60690,15756,3,576,20583,1,3,1528,2304,29062,13064,11444,2215,4437,16786,5803,2554,4094,7596,1,42154,2,39761,6699,31122,4568,11,2,6243,23421,1252,5835,14968,4332,7484,445,2,2,1,26632,5665,2490,7381,15969,873,19634,8,1921,9779,18543,2848,14763,6305,2007,1135,17057,5796,4,14336,14,82,20206,1622,1778,4977,12465,6495,3881,531,991,3030,427,5202,482,3225,6480,1804,8229,1152,1091,270,223,2391,450,5970,2404,10178,324,415,2172,1445,7341,3027,1429,87,116,1609,4198,2,2
# ...
